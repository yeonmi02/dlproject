# %% [markdown]
# <a href="https://colab.research.google.com/github/yeonmi02/dlproject/blob/main/%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8_%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%85%8B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

patient = pd.read_csv('/content/drive/MyDrive/hospital data analysis.csv')
patient.head(10)
# Out:
#    Patient_ID  Age  Gender          Condition                  Procedure  \
# 0           1   45  Female      Heart Disease                Angioplasty
# 1           2   60    Male           Diabetes            Insulin Therapy
# 2           3   32  Female      Fractured Arm           X-Ray and Splint
# 3           4   75    Male             Stroke     CT Scan and Medication
# 4           5   50  Female             Cancer   Surgery and Chemotherapy
# 5           6   68    Male       Hypertension  Medication and Counseling
# 6           7   55  Female       Appendicitis               Appendectomy
# 7           8   40    Male      Fractured Leg  Cast and Physical Therapy
# 8           9   70  Female       Heart Attack    Cardiac Catheterization
# 9          10   25    Male  Allergic Reaction      Epinephrine Injection
#
#     Cost  Length_of_Stay Readmission    Outcome  Satisfaction
# 0  15000               5          No  Recovered             4
# ...

# %% [markdown]
# # 1.1 Data Dictionary
#
# ## 1. age: age in years
#
# ## 2. sex: sex
# - 1 = male
# - 0 = female
#
# ## 3. cd : condition type
# - Value 0: Internal Medicine
# - Value 1: General Surgery
# - Value 2: Chest surgery
# - Value 3: Urology
# - Value 4: Ear & Nose & Throat, otolaryngology
#
# ## 4. Procedure type
# - Value 0: surgery
# - Value 1: medication
# - Value 2: various tests
# - Value 3: Consultation and Management
#
# ## 5. Cost
# - 0 = Cost > 8,370$
# - 1 = Cost < 8,370$
#
# ## 6. Length_of_Stay
# - Length_of_Stay > 37 = 1
# - Length_of_Stay < 37 = 0
#
# ## 7. Readmission
# - 0 = YES
# - 1 = NO
#
# ## 8. Satisfaction
# - 1 = Satisfaction < 3
# - 0 = Satisfaction > 3
#
# ## 9. target : Outcome
# - 0 = Recovered
# - 1 = Stable
