# %% [markdown]
# <a href="https://colab.research.google.com/github/yeonmi02/dlproject/blob/main/%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8_%EC%A0%9C%EC%95%88%EC%84%9C_md.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 프로젝트 제안서
#
# ## 1. 프로젝트 개요
#
#
# *  프로젝트 이름 : 병원 환자 치료 예측
# *  작성자 : 김연미
# *  작성일 : 2025년 3월 26일
#
# ## 2. 배경 및 필요성
#
#
# *  병원 환자들의 치료 데이터와 비용 데이터를 수집한 후 분석하여 각 질병 별 치료 가능성과 비용을 예측할 수 있음
#
# ## 3. 데이터 셋
#
#
# *   참고할 데이터 셋은 인구 통계 정보, 건강 상태, 시행된 치료, 발생한 의료비, 현재 건강 상태를 포함하여 병원에서 치료받은 1000명의 환자에 대한 기록이 포함되어 있습니다. [링크 텍스트](https://www.kaggle.com/datasets/blueblushed/hospital-dataset-for-practice)
#
#
# ![화면 캡처 2025-04-01 103627.png](data:image/png;base64,...)
#
#
#
#
#
#
#
# ## 4. 목표
#
# * 병원 환자들의 데이터를 성공적으로 수집하고 분석과 분류를 한 다음 각각의 질병별 치료 가능성을 예측하고 비용까지 알아보기
#
# ## 5. 주요 기능 및 특징
#
# * 기능 1 : 환자의 치료의 추이를 알아볼 수 있는 기능
# * 기능 2 : 각각의 질병에 대한 비용을 예측할 수 있다
# * 기능 3 : 환자의 치료 방향성에 대한 예측 가능
#
# ## . 기대 효과
#
# * 질병이 걸린 환자들이 자신의 질병에 대한 치료 가능성과 비용을 알아볼 수 있는 기대가 있다
#
# ## 7. 일정 계획
#
# ## 8. 예산
#
# * 없음
#
# ## 9. 팀 구성
#
# * 김연미 : 코드 구성
#
# ## 10. 결론
#
# * 환자 진료에 대한 데이터 셋으로 목표한 예측을 구성하는 것이 결론입니다.
#
# ## 11. 기존 프로젝트의 문제점 개선
#
#
# *   참고한 프로젝트에는 질병의 종류가 너무 다양하고 방대해서 간단하게 정보를 처리할 수 없다는 점이 문제점이라고 생각해서 큰 카테고리를 나눠서 질병을 정리하고 그에 맞는 데이터 셋으로 조정하는 것으로 개선할 생각입니다.
#
# ## 12. 실제 환경 개선과 반영 제안
#
#
# *   데이터 셋에 나와있는 데이터들을 기준에 맞게 배열하고 환자의 질병과 치료 방법, 비용에 대한 환경을 더 간단하게 환경을 구성하지만 정확도는 높일 수 있는 방향으로 개선할 생각입니다.
#
# ## 13. 기존 프로젝트의 성능을 개선
#
# *   참고한 프로젝트의 성능을 높이기 위해 이론 수업시간에 배운 특성 공학과 규제를 사용하여 개선하거나 정규화 기법을 사용하는 방식으로 성능을 개선할 계획입니다.
